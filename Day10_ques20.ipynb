# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %% [markdown]
# # A. Daily attendance of bike tracks
# every row contains the number of bicycles on every track of the city(montreal),
# for every day of the year.
# Can you infer anything from the attendence record?
#
# url = "https://raw.githubusercontent.com/ndas1971/Misc/master/bikes.csv"
#
# 1. Read
# 2. Check head
# 3. Check summary statistics
# 4. plot the daily attendance of two tracks, 'Berri1', 'PierDup'
# 5. Check index , explore weekday_name attributes
# 6. Get sum of all attendance as a function of the weekday
# 7. Display this in figure , what is the inference?

# %%
path = r"C:/Users/Bhavya/handson/code/data/bikes.csv"
bikes = pd.read_csv(path)

# %%
bikes
# Out:
#            Date Unnamed: 1  Berri1   CSC  Mais1  Mais2  Parc  PierDup  \
# 0    01/01/2013      00:00       0     0      1      0     6        0
# 1    02/01/2013      00:00      69     0     13      0    18        0
# 2    03/01/2013      00:00      69     2     21      6    22        1
# 3    04/01/2013      00:00      80     0     22      4    16        0
# 4    05/01/2013      00:00      52     4     19      3    12        0
# ..          ...        ...     ...   ...    ...    ...   ...      ...
# 256  14/09/2013      00:00    2488  1494   1706   2911   979     1075
# 257  15/09/2013      00:00    2243  1749   1417   2933  1804     1459
# 258  16/09/2013      00:00    4206  2466   2799   5485  3272      855
# 259  17/09/2013      00:00    5506  3153   3563   6626  3882     1485
# 260  18/09/2013      00:00    1564  3330   1154   1803  4074     1759
#
#      Rachel1  Totem_Laurier
# 0          1              0
# 1          2              0
# 2          0              0
# ...

# %%
bikes.head()
# Out:
#          Date Unnamed: 1  Berri1  CSC  Mais1  Mais2  Parc  PierDup  Rachel1  \
# 0  01/01/2013      00:00       0    0      1      0     6        0        1
# 1  02/01/2013      00:00      69    0     13      0    18        0        2
# 2  03/01/2013      00:00      69    2     21      6    22        1        0
# 3  04/01/2013      00:00      80    0     22      4    16        0      125
# 4  05/01/2013      00:00      52    4     19      3    12        0       97
#
#    Totem_Laurier
# 0              0
# 1              0
# 2              0
# 3              0
# 4              0

# %%
bikes.columns
# Out:
# Index(['Date', 'Unnamed: 1', 'Berri1', 'CSC', 'Mais1', 'Mais2', 'Parc',
#        'PierDup', 'Rachel1', 'Totem_Laurier'],
#       dtype='object')

# %%
len(bikes)
# Out:
# 261

# %%
bikes.index
# Out:
# RangeIndex(start=0, stop=261, step=1)

# %%
bikes.dtypes
# Out:
# Date             object
# Unnamed: 1       object
# Berri1            int64
# CSC               int64
# Mais1             int64
# Mais2             int64
# Parc              int64
# PierDup           int64
# Rachel1           int64
# Totem_Laurier     int64
# dtype: object

# %%
bikes.describe()
# Out:
#             Berri1          CSC        Mais1        Mais2         Parc  \
# count   261.000000   261.000000   261.000000   261.000000   261.000000
# mean   2743.390805  1221.858238  1757.590038  3224.130268  1669.425287
# std    2247.957848  1070.037364  1458.793882  2589.514354  1363.738862
# min       0.000000     0.000000     1.000000     0.000000     6.000000
# 25%     392.000000    12.000000   236.000000   516.000000   222.000000
# 50%    2771.000000  1184.000000  1706.000000  3178.000000  1584.000000
# 75%    4767.000000  2168.000000  3158.000000  5812.000000  3068.000000
# max    6803.000000  3330.000000  4716.000000  7684.000000  4103.000000
#
#            PierDup      Rachel1  Totem_Laurier
# count   261.000000   261.000000     261.000000
# mean   1152.885057  3084.425287    1858.793103
# std    1208.848429  2380.255540    1434.899574
# min       0.000000     0.000000       0.000000
# 25%      12.000000   451.000000     340.000000
# ...

# %%
# setting date column as index
bikes['Date'] = pd.to_datetime(bikes['Date'], dayfirst=True)
bikes.set_index('Date', inplace=True)

# %%
# plotting graph 
bikes[['Berri1', 'PierDup']].plot()
plt.ylabel('no. of bikes')
plt.show()

# %%
# checking index
bikes.index
# Out:
# DatetimeIndex(['2013-01-01', '2013-01-02', '2013-01-03', '2013-01-04',
#                '2013-01-05', '2013-01-06', '2013-01-07', '2013-01-08',
#                '2013-01-09', '2013-01-10',
#                ...
#                '2013-09-09', '2013-09-10', '2013-09-11', '2013-09-12',
#                '2013-09-13', '2013-09-14', '2013-09-15', '2013-09-16',
#                '2013-09-17', '2013-09-18'],
#               dtype='datetime64[ns]', name='Date', length=261, freq=None)

# %%
# explore weekday_name attributes
bikes['Weekday'] = bikes.index.day_name()

# %%
bikes.head()
# Out:
#            Unnamed: 1  Berri1  CSC  Mais1  Mais2  Parc  PierDup  Rachel1  \
# Date
# 2013-01-01      00:00       0    0      1      0     6        0        1
# 2013-01-02      00:00      69    0     13      0    18        0        2
# 2013-01-03      00:00      69    2     21      6    22        1        0
# 2013-01-04      00:00      80    0     22      4    16        0      125
# 2013-01-05      00:00      52    4     19      3    12        0       97
#
#             Totem_Laurier    Weekday
# Date
# 2013-01-01              0    Tuesday
# 2013-01-02              0  Wednesday
# 2013-01-03              0   Thursday
# 2013-01-04              0     Friday
# 2013-01-05              0   Saturday

# %%
# sum of all attendance as a function of the weekday
weekday_sum = bikes.groupby('Weekday').sum()

# %%
weekday_sum
# Out:
#                                                   Unnamed: 1  Berri1    CSC  \
# Weekday
# Friday     00:0000:0000:0000:0000:0000:0000:0000:0000:000...  105701  44252
# Monday     00:0000:0000:0000:0000:0000:0000:0000:0000:000...  106826  51646
# Saturday   00:0000:0000:0000:0000:0000:0000:0000:0000:000...   75754  27226
# Sunday     00:0000:0000:0000:0000:0000:0000:0000:0000:000...   74873  29181
# Thursday   00:0000:0000:0000:0000:0000:0000:0000:0000:000...  115193  52340
# Tuesday    00:0000:0000:0000:0000:0000:0000:0000:0000:000...  117244  54656
# Wednesday  00:0000:0000:0000:0000:0000:0000:0000:0000:000...  120434  59604
#
#            Mais1   Mais2   Parc  PierDup  Rachel1  Totem_Laurier
# Weekday
# Friday     71605  127526  64385    36850   118556          71426
# Monday     68087  129982  69767    44500   119211          72883
# Saturday   45947   79743  35544    46149    97143          56438
# Sunday     40812   75746  37620    53812   100735          53798
# ...

# %%
order = ['Monday', 'Tuesday', 'Wednesday', 'Thursday', 'Friday', 'Saturday', 'Sunday']
weekday_sum1 = weekday_sum.reindex(order)

# %%
weekday_sum1
# Out:
#                                                   Unnamed: 1  Berri1    CSC  \
# Weekday
# Monday     00:0000:0000:0000:0000:0000:0000:0000:0000:000...  106826  51646
# Tuesday    00:0000:0000:0000:0000:0000:0000:0000:0000:000...  117244  54656
# Wednesday  00:0000:0000:0000:0000:0000:0000:0000:0000:000...  120434  59604
# Thursday   00:0000:0000:0000:0000:0000:0000:0000:0000:000...  115193  52340
# Friday     00:0000:0000:0000:0000:0000:0000:0000:0000:000...  105701  44252
# Saturday   00:0000:0000:0000:0000:0000:0000:0000:0000:000...   75754  27226
# Sunday     00:0000:0000:0000:0000:0000:0000:0000:0000:000...   74873  29181
#
#            Mais1   Mais2   Parc  PierDup  Rachel1  Totem_Laurier
# Weekday
# Monday     68087  129982  69767    44500   119211          72883
# Tuesday    76974  141217  74299    40679   123533          76559
# Wednesday  79033  145860  80437    42564   125173          79501
# Thursday   76273  141424  73668    36349   120684          74540
# ...

# %%
# plotting graph showing each day sum
weekday_sum1.plot(kind='bar', title='Total Bike Attendance')
plt.show()

# %%
# Inference
# By observing the above graph, we can infer that more bikes are used on wweekdays(i.e,from Monday to friday)

# %% [markdown]
# # B. Titanic
# https://www.kaggle.com/c/titanic/data
#
# Database of whether somebody survived or not
# Can you infer who has survived ?
#
# 1. Load the data
# 2. Which gender survived more
# 3. Does it depend on pclass?
# 4. can we see % of survival of each gender and pclass
# What is your inference?

# %%
path1 = r"C:\Users\Bhavya\handson\code\data\titanic_train.csv"
titanic = pd.read_csv(path1)

# %%
titanic
# Out:
#      survived  pclass                                               name  \
# 0           0       3                            Braund, Mr. Owen Harris
# 1           1       1  Cumings, Mrs. John Bradley (Florence Briggs Th...
# 2           1       3                             Heikkinen, Miss. Laina
# 3           1       1       Futrelle, Mrs. Jacques Heath (Lily May Peel)
# 4           0       3                           Allen, Mr. William Henry
# ..        ...     ...                                                ...
# 886         0       2                              Montvila, Rev. Juozas
# 887         1       1                       Graham, Miss. Margaret Edith
# 888         0       3           Johnston, Miss. Catherine Helen "Carrie"
# 889         1       1                              Behr, Mr. Karl Howell
# 890         0       3                                Dooley, Mr. Patrick
#
#         sex   age  sibsp  parch            ticket     fare cabin embarked
# ...

# %%
titanic.head()
# Out:
#    survived  pclass                                               name  \
# 0         0       3                            Braund, Mr. Owen Harris
# 1         1       1  Cumings, Mrs. John Bradley (Florence Briggs Th...
# 2         1       3                             Heikkinen, Miss. Laina
# 3         1       1       Futrelle, Mrs. Jacques Heath (Lily May Peel)
# 4         0       3                           Allen, Mr. William Henry
#
#       sex   age  sibsp  parch            ticket     fare cabin embarked
# 0    male  22.0      1      0         A/5 21171   7.2500   NaN        S
# 1  female  38.0      1      0          PC 17599  71.2833   C85        C
# 2  female  26.0      0      0  STON/O2. 3101282   7.9250   NaN        S
# 3  female  35.0      1      0            113803  53.1000  C123        S
# 4    male  35.0      0      0            373450   8.0500   NaN        S

# %%
titanic.index
# Out:
# RangeIndex(start=0, stop=891, step=1)

# %%
titanic.dtypes
# Out:
# survived      int64
# pclass        int64
# name         object
# sex          object
# age         float64
# sibsp         int64
# parch         int64
# ticket       object
# fare        float64
# cabin        object
# embarked     object
# dtype: object

# %%
len(titanic)
# Out:
# 891

# %%
titanic.columns
# Out:
# Index(['survived', 'pclass', 'name', 'sex', 'age', 'sibsp', 'parch', 'ticket',
#        'fare', 'cabin', 'embarked'],
#       dtype='object')

# %%
# Which gender survived more 
titanic.groupby('sex')['survived'].sum()
# Out:
# sex
# female    233
# male      109
# Name: survived, dtype: int64

# %%
# Does survival depend on Pclass?
titanic.groupby('pclass')['survived'].mean()
# Out:
# pclass
# 1    0.629630
# 2    0.472826
# 3    0.242363
# Name: survived, dtype: float64

# %%
# % of survival of each gender and pclass
survival_rate = titanic.pivot_table(index='sex', columns='pclass', values='survived', aggfunc='mean')

# %%
survival_rate*100
# Out:
# pclass          1          2          3
# sex
# female  96.808511  92.105263  50.000000
# male    36.885246  15.740741  13.544669

# %%
# Inference
# By observing above values, we can say female survival rate is higher compared to male.
# considering pclass, 1st class females have more survival rate and 3rd class males have low survival rate

# %% [markdown]
# # C. Roger Federer database
#
# Each row corresponds to a ATP match played by Roger Federer
#
# Can you infer anything on Roger Federer performance?
#
# player = 'Roger Federer'
# url = "https://raw.githubusercontent.com/ndas1971/Misc/master/federer.csv"
#
# 1. Read and check data
# 2. How many % of matched won by our player? ('winner')
# 3. Proportion of double faults wrt total points in each match
# This number is an indicator of the player's state of mind, his level of self-confidence,
# his willingness to take risks while serving, and other parameters.
# columns:
# 'player1 double faults' and 'player1 total points total'
# Display simple stats of above
# 4. Average Win per surface
# 5. Display the proportion of double faults as a function of the tournament date, 'start date'
# Trend: display average double faults in each year

# %%
path2 = r"C:\Users\Bhavya\handson\code\data\federer.csv"
federer = pd.read_csv(path2)

# %%
federer
# Out:
#       year                  tournament  start date type        surface  \
# 0     1998          Basel, Switzerland  05.10.1998   WS   Indoor: Hard
# 1     1998            Toulouse, France  28.09.1998   WS   Indoor: Hard
# 2     1998            Toulouse, France  28.09.1998   WS   Indoor: Hard
# 3     1998            Toulouse, France  28.09.1998   WS   Indoor: Hard
# 4     1998         Geneva, Switzerland  24.08.1998   CH  Outdoor: Clay
# ...    ...                         ...         ...  ...            ...
# 1174  2012  Australian Open, Australia  16.01.2012   GS  Outdoor: Hard
# 1175  2012                 Doha, Qatar  02.01.2012  250  Outdoor: Hard
# 1176  2012                 Doha, Qatar  02.01.2012  250  Outdoor: Hard
# 1177  2012                 Doha, Qatar  02.01.2012  250  Outdoor: Hard
# 1178  2012                 Doha, Qatar  02.01.2012  250  Outdoor: Hard
#
#            draw atp points  atp ranking tournament prize money round  ...  \
# ...

# %%
federer.head()
# Out:
#    year           tournament  start date type        surface      draw  \
# 0  1998   Basel, Switzerland  05.10.1998   WS   Indoor: Hard  Draw: 32
# 1  1998     Toulouse, France  28.09.1998   WS   Indoor: Hard  Draw: 32
# 2  1998     Toulouse, France  28.09.1998   WS   Indoor: Hard  Draw: 32
# 3  1998     Toulouse, France  28.09.1998   WS   Indoor: Hard  Draw: 32
# 4  1998  Geneva, Switzerland  24.08.1998   CH  Outdoor: Clay  Draw: 32
#
#   atp points  atp ranking tournament prize money round  ...  \
# 0          1        396.0                 $9,800   R32  ...
# 1         59        878.0                $10,800   R32  ...
# 2         59        878.0                $10,800   R16  ...
# 3         59        878.0                $10,800     Q  ...
# 4          1        680.0                   $520   R32  ...
#
#   player2 2nd serve return points total player2 break points converted won  \
# 0                                  22.0                                4.0
# ...

# %%
federer.index
# Out:
# RangeIndex(start=0, stop=1179, step=1)

# %%
federer.columns
# Out:
# Index(['year', 'tournament', 'start date', 'type', 'surface', 'draw',
#        'atp points', 'atp ranking', 'tournament prize money', 'round',
#        'opponent', 'ranking', 'score', 'stats link', 'tournament.1',
#        'tournament round', 'time', 'winner', 'player1 name',
#        'player1 nationality', 'player1 aces', 'player1 double faults',
#        'player1 1st serves in', 'player1 1st serves total',
#        'player1 1st serve points won', 'player1 1st serve points total',
#        'player1 2nd serve points won', 'player1 2nd serve points total',
#        'player1 break points won', 'player1 break points total',
#        'player1 service games played', 'player1 1st serve return points won',
#        'player1 1st serve return points total',
#        'player1 2nd serve return points won',
#        'player1 2nd serve return points total',
#        'player1 break points converted won',
#        'player1 break points converted total', 'player1 return games played',
# ...

# %%
federer.dtypes
# Out:
# year                                    int64
# tournament                             object
# start date                             object
# type                                   object
# surface                                object
#                                        ...
# player2 total service points total    float64
# player2 total return points won       float64
# player2 total return points total     float64
# player2 total points won              float64
# player2 total points total            float64
# Length: 70, dtype: object

# %%
len(federer)
# Out:
# 1179

# %%
wins = federer[federer['winner']==federer['player1 name']]
win_percent = (len(wins)/len(federer)) * 100
win_percent
# Out:
# 82.44274809160305

# %%
# double fault ratio
federer['df_ratio'] = federer['player1 double faults'] / federer['player1 total points total']
federer.df_ratio
# Out:
# 0       0.019417
# 1       0.000000
# 2       0.020270
# 3       0.046154
# 4            NaN
#           ...
# 1174    0.018116
# 1175    0.000000
# 1176    0.000000
# 1177    0.011561
# 1178         NaN
# Name: df_ratio, Length: 1179, dtype: float64

# %%
federer['df_ratio'].describe()
# Out:
# count    1027.000000
# mean        0.012129
# std         0.010797
# min         0.000000
# 25%         0.004444
# 50%         0.010000
# 75%         0.018108
# max         0.060606
# Name: df_ratio, dtype: float64

# %%
# Average Win per surface
wins = federer[federer['winner'] == federer['player1 name']]
total_surface = federer['surface'].value_counts()
win_surface = wins['surface'].value_counts()
win_surface_rate = (win_surface/total_surface)*100 
win_surface_rate
# Out:
# surface
# Outdoor: Hard     84.232365
# Outdoor: Clay     77.911647
# Indoor: Hard      83.628319
# Outdoor: Grass    87.142857
# Indoor: Carpet    73.684211
# Indoor: Clay      83.333333
# Name: count, dtype: float64

# %%
# Display the proportion of double faults as a function of the tournament date, 'start date'

federer['start date'] = pd.to_datetime(federer['start date'], errors='coerce')
federer['year'] = federer['start date'].dt.year

# %%
df_avg_yearly = federer.groupby('year')['df_ratio'].mean()
df_avg_yearly
# Out:
# year
# 1998.0    0.020738
# 1999.0    0.028285
# 2000.0    0.020918
# 2001.0    0.016780
# 2002.0    0.016084
# 2003.0    0.018211
# 2004.0    0.012856
# 2005.0    0.008778
# 2006.0    0.008495
# 2007.0    0.009116
# 2008.0    0.005306
# 2009.0    0.008313
# 2010.0    0.009711
# 2011.0    0.008275
# 2012.0    0.011024
# Name: df_ratio, dtype: float64

# %%
# Trend: display average double faults in each year 
df_avg_yearly.plot(kind='line',title='Double Fault ratio by year')
plt.ylabel('Double fault ratio')
plt.show()

# %% [markdown]
# <h2>
# D. Create two frequencies 5Hz and 50Hz sin signals
#     Draw FFT components
#     <h2/>

# %%
f1=5
f2=50
fs=500 #500 samples per sec
T = 1 # time in sec
t = np.linspace(0,T,fs*T, endpoint=False)

# %%
signal_5=np.sin(2*np.pi*f1*t)
signal_50=np.sin(2*np.pi*f2*t)

# %%
fft_vals1 = np.fft.fft(signal_5) #fft for 5
fft_freqs1 = np.fft.fftfreq(len(signal_5), 1/fs)

# %%
fft_vals2 = np.fft.fft(signal_50) #fft for 50
fft_freqs2 = np.fft.fftfreq(len(signal_50), 1/fs)

# %%
#converting to df
fft_df1 = pd.DataFrame({'Frequency': fft_freqs1, 'Amplitude': np.abs(fft_vals1)})
fft_df2 = pd.DataFrame({'Frequency': fft_freqs2, 'Amplitude': np.abs(fft_vals2)})

# %%
fft_df1 = fft_df1[fft_df1['Frequency'] > 0]
fft_df2 = fft_df2[fft_df2['Frequency'] > 0] # for only +ve freq's

# %%
# Plotting FFT for the 5 Hz signal
plt.figure(figsize=(10, 5))
plt.subplot(1, 2, 1)
plt.plot(fft_df1['Frequency'], fft_df1['Amplitude'])
plt.title("FFT of 5 Hz Signal")
plt.xlabel("Frequency (Hz)")
plt.ylabel("Amplitude")
plt.grid(True)

# Plotting FFT for the 50 Hz signal
plt.subplot(1, 2, 2)
plt.plot(fft_df2['Frequency'], fft_df2['Amplitude'])
plt.title("FFT of 50 Hz Signal")
plt.xlabel("Frequency (Hz)")
plt.ylabel("Amplitude")
plt.grid(True)

plt.tight_layout()
plt.show()

# %% [markdown]
# <h1>E.
# Plotting normal random numbers
# and show that addition of two Gaussian is Gaussian
# and addition of all is Gaussian</h1>

# %%
# Parameters
n = 10000 # no.of samples
mean = 0 # mean
sd=1 # standard deviation

# %%
# generating normal random numbers
gaussian_1 = np.random.normal(mean, sd, n)
gaussian_2 = np.random.normal(mean, sd, n)
sum_two_gaussians = gaussian_1 + gaussian_2

# %%
# adding n gaussians
n_gaussians = 5
sum_n_gaussians = np.zeros(n)
for _ in range(n_gaussians):
    sum_n_gaussians += np.random.normal(mean, sd, n)

# %%
df = pd.DataFrame({
    'gaussian_1': gaussian_1,
    'gaussian_2': gaussian_2,
    'sum_two_gaussians': sum_two_gaussians,
    'sum_n_gaussians': sum_n_gaussians
})

# %%
# Plotting histograms
plt.figure(figsize=(12, 8))

# Plot Gaussian 1 and Gaussian 2
plt.subplot(2, 2, 1)
plt.hist(gaussian_1, bins=50, alpha=0.7, label='Gaussian 1')
plt.hist(gaussian_2, bins=50, alpha=0.7, label='Gaussian 2')
plt.title('Gaussian 1 & Gaussian 2')
plt.legend()

# Plot sum of two Gaussians
plt.subplot(2, 2, 2)
plt.hist(sum_two_gaussians, bins=50, alpha=0.7, color='g', label='Sum of Two Gaussians')
plt.title('Sum of Two Gaussians')
plt.legend()

# Plot sum of multiple Gaussians
plt.subplot(2, 2, 3)
plt.hist(sum_multiple_gaussians, bins=50, alpha=0.7, color='r', label='Sum of Multiple Gaussians')
plt.title('Sum of Multiple Gaussians')
plt.legend()

plt.tight_layout()
plt.show()
